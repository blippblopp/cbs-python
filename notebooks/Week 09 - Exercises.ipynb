# %% [markdown]
# # Week 09 - Exercises
#
# In this week's exercises I want you to do them in your **editor** using the template from the lecture notes.
#
# <ol>
#     <li>Open up your python editor (Spyder, Komodo, Sublime-text, etc.)</li>
#     <li>Create a new file</li>
#     <li>Copy the template from the lecture notes into your editor</li>
#     <li>Save the file as exercise.py in your course directory</li>
#     <li>Test that everything works, by opening up a terminal or command prompt and navigate to the destination of your file.
#     eg. <br>
#     <cb>cd Documents/Courses/cbs-python/</cb>, or <br>
#     <cb>cd C:\Users\csh\Documents\cbs-python\</cb> <br>
#     (might be different on your machines)
#     <li>Run the command <cb>python exercise.py -f test1 -o test2 </cb> to test the result. Make sure you get the output as below (with no errors): </li>
# </ol>

# %% [raw]
# # exercise.py -f test1 -o test2
# # Wed Nov 06 2013 11:03
# # USER: christian
# # CWD: /home/christian/Dropbox/PhD/project/src/python
# # HOST: Linux x86_64 3.8.0-32-generic csh-laptop
# # COMMAND LINE PARAMETERS SET TO:
# # 	fasta_file                    test1
# # 	first_parameter               0.5
# # 	output_file                   test2
# # 	second_parameter              0
# Input file is: test1
# Output file is: test2
# Paramter 1 is: 0.5
# Paramter 2 is: 0

# %% [markdown]
# **Troubleshooting**: In windows, if you see an error like

# %% [raw]
# 'python' is not recognized as an internal or external command, operable program or batch file.

# %% [markdown]
# then you need to make sure that your computer knows where to find the Python interpreter. Follow the 5 steps in the lecture notes under *Making command line work in Windows*.

# %% [markdown]
# <q>BioPython Playground</q>
# In this exercise we will test some of the features in BioPython, namely
#
# <ol>
#     <li>Importing Fasta files</li>
#     <li>Running BLAST jobs</li>
#     <li>Fetching gene/protein information</li>
#     <li>Outputting Fasta files</li>
# </ol>

# %% [markdown]
# Make a program (exercise.py) following the instructions below
# I have written some quite course instructions here with hints about what you have to import to do the task. The secondary objective to this exercise is to let you walk through the steps on your own, finding the necessary information inside python.
#
# <ol>
#     <li>Import the fasta input file given by the user (-f) using BioPython</li>
#         (```from Bio import SeqIO```)
#     <li>Run an online blast against the sequence using blastx as program and nr as database</li>
#     (```from Bio.Blast import NCBIWWW```)
#     <li>Obtain the accession number and E-value of the best match</li>
#     (```from Bio.Blast import NCBIXML```)<br />
#     **Hint**: The accession number is in the alignment object, while the E-value is in ```hsps[0].expect``` of the alignment object)
#     <li>Use Entrez to fetch some information about this protein, in a fasta format</li>
#     (```from Bio import Entrez```)
#     <li>Save the sequence in fasta format to the output file given by the user (-o) using SeqIO</li>
#     <li>Print messages in between the steps to let the user know what is happening</li>
#     (use "#" in the beginning of the lines printed to the user)
#     <li>Test the program with: <br />
#     <cb>python exercise.py -f data/unknown.fasta -o output.fasta</cb></li>
# </ol>

# %% [markdown]
# ---

# %%
from IPython.core.display import HTML


def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     div.text_cell_render{
#         font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 100%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     div.CodeMirror{
#     	font-size: 11pt;
#     }
#     div.cell.border-box-sizing.code_cell{
#     	padding-left: 50px;
#     }
#     div.text_cell_input {
#     	margin-left: 50px;
#     }
#     .prompt{
#         display: None;
#     }
#     .text_cell_render h1 {
#         font-family: Helvetica, serif;
#         font-size: 30pt;
#         color: #274257;
#         text-transform: uppercase;
#         line-height: 100%;
#     }
#     .text_cell_render h2 {
#     	margin-top: 35px;
#         font-family: Helvetica, serif;
#         font-size: 24pt;
#         color: #2A75A9;
#         line-height: 100%;
#     }
#     .text_cell_render h3{
#     	margin-top: 35px;
#         font-family: Helvetica, serif;
#         font-size: 18pt;
#         color: #7EB5D6;
#         line-height: 100%;
#        }
#     .text_cell_render h4{
#     	margin-top: 35px;
#     	font-family: Helvetica, serif;
#         font-size: 14pt;
#         line-height: 100%;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#         line-height: 100%;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
#     .wds {
#         background: none repeat scroll 0% 0% rgb(247, 247, 247);
#         padding: 0em 0em;
#         font-size: 11px;
#         font-family: Arial,Helvetica,sans-serif;
#         display: inline-block;
#         margin: 0px 0em;
#         white-space: nowrap;
#     }
#     cb {
#         background: none repeat scroll 0% 0% rgb(247, 247, 247);
#         padding: 0.1em 0.6em;
#         border: 1px solid rgb(204, 204, 204);
#         font-size: 11pt;
#         font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#         color: rgb(51, 51, 51);
#         box-shadow: 0px 1px 0px rgba(0, 0, 0, 0.2), 0px 0px 0px 2px rgb(255, 255, 255) inset;
#         border-radius: 3px 3px 3px 3px;
#         display: inline-block;
#         margin: 0px 0.1em;
#         line-height: 1.4;
#         white-space: nowrap;
#     }
#     q {
#         font-weight: 300;
#         font-size: 14pt;
#         color: #4057A1;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#         font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     qq {
#         font-weight: 300;
#         font-size: 11pt;
#         color: #4057A1;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#         font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     kbd {
#         background: none repeat scroll 0% 0% rgb(247, 247, 247);
#         padding: 0.1em 0.6em;
#         border: 1px solid rgb(204, 204, 204);
#         font-size: 11px;
#         font-family: Arial,Helvetica,sans-serif;
#         color: rgb(51, 51, 51);
#         box-shadow: 0px 1px 0px rgba(0, 0, 0, 0.2), 0px 0px 0px 2px rgb(255, 255, 255) inset;
#         border-radius: 3px 3px 3px 3px;
#         display: inline-block;
#         margin: 0px 0.1em;
#         text-shadow: 0px 1px 0px rgb(255, 255, 255);
#         line-height: 1.4;
#         white-space: nowrap;
#     }
#     ol {
#         list-style-type: decimal;
#     }
#
# 	.box_rotate {
# 		  -webkit-transform: rotate(270deg);  /* Chrome, Safari 3.1+ */
# 		     -moz-transform: rotate(270deg);  /* Firefox 3.5-15 */
# 		      -ms-transform: rotate(270deg);  /* IE 9 */
# 		       -o-transform: rotate(270deg);  /* Opera 10.50-12.00 */
# 		          transform: rotate(270deg);  /* Firefox 16+, IE 10+, Opera 12.10+ */
# 	}
#
# 	.vertical-text {
# 		display: inline-block;
# 		overflow: hidden;
# 		width: 1.5em;
# 	}
#
# 	.vertical-text__inner {
# 		display: inline-block;
# 		white-space: nowrap;
# 		line-height: 1.5;
# 		  -webkit-transform: rotate(270deg);  /* Chrome, Safari 3.1+ */
# 		     -moz-transform: rotate(270deg);  /* Firefox 3.5-15 */
# 		      -ms-transform: rotate(270deg);  /* IE 9 */
# 		       -o-transform: rotate(270deg);  /* Opera 10.50-12.00 */
# 		          transform: rotate(270deg);  /* Firefox 16+, IE 10+, Opera 12.10+ */
# 	}
#
# 	.vertical-text__inner:after {
# 		content: "";
# 		display: block;
# 		margin: -1.5em 0 100%;
# 	}
#
# 	.topics{
# 		background: url('files/images/topics.png') no-repeat scroll 0% 0%;
# 		width: 520px;
# 		height: 250px;
#
# 		padding-top: 35px;
# 	}
#
# 	.c_program{
# 		background: url('files/images/program.png') no-repeat scroll 0% 0%; width: 520px; margin-left: auto; margin-right: auto;
# 	}
#
# 	.c_require{
# 		background: url('files/images/software.png') no-repeat scroll 0% 0%; width: 520px; height: 250px; margin-left: auto; margin-right: auto;
# 	}
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
