# %% [markdown]
# ![Welcome](../pix/python-27624.png)

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <div class="c_program">
#     <br />
#
#
#
#
#     <table width="450px">
#         <tr style="border-bottom: 2px solid black;">
#             <td width="20px">
#             </td><td width="20px"><b>#</b></td>
#             <td width="75px"><b>Date</b></td>
#             <td width="200px"><b>Lesson</b></td>
#         </tr>
#          <tr>
#              <th rowspan="4">
#                  <div class="vertical-text">
#                      <div class="vertical-text__inner">Fundamentals</div>
#                  </div>
#              </th>
#              <td>1</td>
#              <td>4. Sep</td>
#              <td>Welcome, Introduction to Python</td>
#         </tr>
#          <tr>
#              <td>2</td>
#              <td>11. Sep</td>
#              <td>Basic Python 1: Organising Data</td>
#         </tr>
#          <tr>
#              <td>3</td>
#              <td>18. Sep</td>
#              <td>Basic Python 2: Decisions and Control </td>
#         </tr>
#         <tr style="border-bottom: 2px solid black;">
#             <td>4</td>
#             <td>25. Sep</td>
#             <td>Basic Python 3: Dealing with Files</td>
#         </tr>
#         <tr>
#             <th rowspan="5">
#                 <div class="vertical-text">
#                      <div class="vertical-text__inner">Programs</div>
#                  </div>
#             </th>
#             <td>5</td>
#             <td>2. Oct</td>
#             <td>Functions, Modulization and Scripts</td>
#         </tr>
#         <tr>
#             <td>6</td>
#             <td>9. Oct</td>
#             <td>Error Handling</td>
#         </tr>
#         <tr>
#             <td>7</td>
#             <td>23. Oct</td>
#             <td>Classes</td>
#         </tr>
#         <tr>
#             <td>8</td>
#             <td>30. Oct</td>
#             <td>Regular Expressions</td>
#         </tr>
#         <tr style="border-bottom: 2px solid black;">
#             <td>9</td>
#             <td>6. Nov</td>
#             <td>Biopython</td>
#         </tr>
#         <tr>
#             <th rowspan="4">
#                 <div class="vertical-text">
#                      <div class="vertical-text__inner">Project</div>
#                  </div>
#             </th>
#             <td></td>
#             <td>13. Nov</td>
#             <td rowspan="4">Working on project</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>20. Nov</td>
#
#         </tr>
#         <tr>
#             <td></td>
#             <td>27. Nov</td>
#
#         </tr>
#         <tr>
#             <td></td>
#             <td>4. Dec</td>
#
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td>19. Dec</td>
#             <td>Hand in project</td>
#         </tr>
#     </table>
#     <br />
# </div>
#
# <br><br><br><br>

# %% [markdown]
# ### Today
# * Welcome, Introduction to Python
# * Installing Git (a distributed version control system)
# * Using Git to get the course material
# * Install Python, IPython and required modules
# * Get the *Python for Bioinformatics* book from campusnet

# %% [markdown]
# ### Software Requirements
# * Linux or Mac OSX is a great advantage. Windows will work too.
# * Python 2.7 *extra modules: mathlib, numpy*
# * IPython 2.2 *extra modules: tornado, pyzmq, jinja2*
# * Instruction for setting up everything are found in the installation notebook

# %% [markdown]
# ### Preparation
# * Navigate to http://www.cbs.dtu.dk/courses/27624/
# * Get the Course Material
# * Install Python and IPython
# * Get the book from campusnet *Python for Bioinformatics by S. Bassi*

# %% [markdown]
# ---

# %%
from IPython.core.display import HTML


def css_styling():
    styles = open("../styles/custom_slide.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
# 	margin-top:7em;
# 	margin-bottom:7em;
# }
#     }
#     div.text_cell_render{
#         font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 100%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     div.CodeMirror{
#     	font-size: 11pt;
#     }
#     div.cell.border-box-sizing.code_cell{
#     	padding-left: 50px;
#     }
#     div.text_cell_input {
#     	margin-left: 50px;
#     }
#     .prompt{
#         display: None;
#     }
#     .text_cell_render h1 {
#         font-family: Helvetica, serif;
#         font-size: 30pt;
#         color: #274257;
#         text-transform: uppercase;
#         line-height: 100%;
#     }
#     .text_cell_render h2 {
# ...
